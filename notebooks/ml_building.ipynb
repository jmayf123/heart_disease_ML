# %%
import pandas as pd

# %%
data = pd.read_csv('../data/cleaned_data_ML.csv', index_col=0)

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

X = data.drop(columns='Heart_Disease')
y = data['Heart_Disease']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [1:35:19<00:00, 197.21s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.77               0.74     0.74      0.83
# BernoulliNB                        0.84               0.71     0.71      0.87
# GaussianNB                         0.50               0.70     0.70      0.61
# QuadraticDiscriminantAnalysis      0.40               0.65     0.65      0.51
# LinearDiscriminantAnalysis         0.93               0.58     0.58      0.92
# DecisionTreeClassifier             0.90               0.57     0.57      0.90
# ExtraTreeClassifier                0.91               0.56     0.56      0.90
# KNeighborsClassifier               0.93               0.53     0.53      0.92
# BaggingClassifier                  0.93               0.53     0.53      0.91
# CalibratedClassifierCV             0.94               0.53     0.53      0.92
# ExtraTreesClassifier               0.93               0.53     0.53      0.92
# AdaBoostClassifier                 0.94               0.52     0.52      0.92
# LogisticRegression                 0.94               0.52     0.52      0.92
# PassiveAggressiveClassifier        0.93               0.52     0.52      0.91
# XGBClassifier                      0.94               0.52     0.52      0.92
# RandomForestClassifier             0.94               0.52     0.52      0.91
# Perceptron                         0.94               0.51     0.51      0.91
# LGBMClassifier                     0.94               0.51     0.51      0.92
# SVC                                0.94               0.50     0.50      0.91
# LinearSVC                          0.94               0.50     0.50      0.91
# DummyClassifier                    0.94               0.50     0.50      0.91
# RidgeClassifier                    0.94               0.50     0.50      0.91
# RidgeClassifierCV                  0.94               0.50     0.50      0.91
# SGDClassifier                      0.94               0.50     0.50      0.91
#
#                                Time Taken
# Model
# NearestCentroid                      1.22
# BernoulliNB                          1.72
# GaussianNB                           1.51
# QuadraticDiscriminantAnalysis        2.69
# LinearDiscriminantAnalysis           5.40
# DecisionTreeClassifier               3.15
# ExtraTreeClassifier                  1.64
# KNeighborsClassifier               119.26
# BaggingClassifier                   17.19
# CalibratedClassifierCV             445.92
# ExtraTreesClassifier                54.31
# AdaBoostClassifier                  15.86
# LogisticRegression                   2.94
# PassiveAggressiveClassifier          1.64
# XGBClassifier                       27.99
# RandomForestClassifier              30.74
# Perceptron                           1.48
# LGBMClassifier                       3.57
# SVC                               4834.54
# LinearSVC                          135.91
# DummyClassifier                      1.04
# RidgeClassifier                      1.42
# RidgeClassifierCV                    2.48
# SGDClassifier                        2.35
