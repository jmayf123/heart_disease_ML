# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/cleaned_data.csv', index_col=0)

# %%
df['Heart_Disease'].value_counts()
# Out:
# 0.0    268239
# 1.0     16640
# Name: Heart_Disease, dtype: int64

# %%
hd = list((df['Heart_Disease'].value_counts()))
plt.pie(hd, labels=['No Heart Disease', 'Heart Disease'], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Need to work on Class imbalance correction with resampling.

# %%
sns.countplot(data = df, x = 'Sex', hue = 'Heart_Disease')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.histplot(data=df, x='Age_Category', hue='Sex', multiple='dodge', shrink=2.8)
plt.xticks(np.arange(0, 15, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x7fd43eb19030>,
#   <matplotlib.axis.XTick at 0x7fd43eb19000>,
#   <matplotlib.axis.XTick at 0x7fd43eb1bc70>,
#   <matplotlib.axis.XTick at 0x7fd43e887250>,
#   <matplotlib.axis.XTick at 0x7fd43e887d00>,
#   <matplotlib.axis.XTick at 0x7fd43e8b87f0>,
#   <matplotlib.axis.XTick at 0x7fd43e8b92a0>,
#   <matplotlib.axis.XTick at 0x7fd43e8b9d50>,
#   <matplotlib.axis.XTick at 0x7fd43e8b8b20>,
#   <matplotlib.axis.XTick at 0x7fd43e9fcd90>,
#   <matplotlib.axis.XTick at 0x7fd43e94e9e0>,
#   <matplotlib.axis.XTick at 0x7fd43e94cd00>,
#   <matplotlib.axis.XTick at 0x7fd43e8d5390>,
#   <matplotlib.axis.XTick at 0x7fd43e8d75e0>,
#   <matplotlib.axis.XTick at 0x7fd43e94dc00>],
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14')])

# %% [markdown]
# Age Distributions for those with HD and without HD

# %%
df_hd = df[df['Heart_Disease'] == 1]
df_no_hd = df[df['Heart_Disease'] == 0]

# %%
fig,axes=plt.subplots(1,2,figsize=(10,5))

sns.histplot(ax=axes[0],x=df_no_hd['Age_Category'])
sns.histplot(ax=axes[1],x=df_hd["Age_Category"])
axes[0].set_title("No - Heart disease")
axes[1].set_title("Yes - Heart Disease")
axes[0].set_xticks((np.arange(0, 15, step=1)))
axes[1].set_xticks((np.arange(0, 15, step=1)))
# Out:
# [<matplotlib.axis.XTick at 0x7fd43eeca170>,
#  <matplotlib.axis.XTick at 0x7fd43eec9f00>,
#  <matplotlib.axis.XTick at 0x7fd43e7ff850>,
#  <matplotlib.axis.XTick at 0x7fd43dec4a60>,
#  <matplotlib.axis.XTick at 0x7fd43dec5510>,
#  <matplotlib.axis.XTick at 0x7fd43dec5fc0>,
#  <matplotlib.axis.XTick at 0x7fd43e6aada0>,
#  <matplotlib.axis.XTick at 0x7fd43dec4ca0>,
#  <matplotlib.axis.XTick at 0x7fd43dec7520>,
#  <matplotlib.axis.XTick at 0x7fd43ef5e2f0>,
#  <matplotlib.axis.XTick at 0x7fd43df0d8a0>,
#  <matplotlib.axis.XTick at 0x7fd43e5d75b0>,
#  <matplotlib.axis.XTick at 0x7fd43df0e1a0>,
#  <matplotlib.axis.XTick at 0x7fd43df0ec50>,
#  <matplotlib.axis.XTick at 0x7fd43df0f700>]
